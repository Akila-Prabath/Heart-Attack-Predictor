# %%
import joblib
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %%
X_test = joblib.load("../../models/FC212013_Maleesha/X_test.pkl")
y_test = joblib.load("../../models/FC212013_Maleesha/y_test.pkl")
base_model = joblib.load("../../models/FC212013_Maleesha/xgboost_model.pkl")
tuned_model = joblib.load("../../models/FC212013_Maleesha/xgboost_best.pkl")

# %%
base_pred = base_model.predict(X_test)
tuned_pred = tuned_model.predict(X_test)

# %%
print("=== Base Model Report ===")
print(classification_report(y_test, base_pred))
# Out:
# === Base Model Report ===
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     18906
#            1       0.40      1.00      0.57     12765
#
#     accuracy                           0.40     31671
#    macro avg       0.20      0.50      0.29     31671
# weighted avg       0.16      0.40      0.23     31671
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
print("\n=== Tuned Model Report ===")
print(classification_report(y_test, tuned_pred))
# Out:
# === Tuned Model Report ===
#               precision    recall  f1-score   support
#
#            0       0.76      0.81      0.79     18906
#            1       0.69      0.62      0.66     12765
#
#     accuracy                           0.74     31671
#    macro avg       0.73      0.72      0.72     31671
# weighted avg       0.73      0.74      0.74     31671

# %%
cm = confusion_matrix(y_test, tuned_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix - Tuned Model")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
